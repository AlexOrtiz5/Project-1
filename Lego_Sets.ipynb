# %% [markdown]
# # Import the Libraries that are going to be used:

# %%
import pandas as pd

# %% [markdown]
# # Read the csv file

# %% [markdown]
# ## Before reading the csv file
#
# ### Instructions:
# 1. Download the Dataset from the page: https://www.kaggle.com/datasets/alessiasimone/lego-sets-and-price-1955-2023/.
# 2. After downloading extract the file in the location you want to use.
# 3. Then change the name of the file from Output.csv to which name you want to use.
# 4. Now you can enjoy the code by changing the name of the file in the read_csv.

# %%
Lego_df = pd.read_csv('lego_sets_data.csv', dtype={'column_9': int}, low_memory=False,sep=';')

# %%
Lego_df
# Out:
#          year Theme name          Sets Name  \
# 0        2016   Skylines             London
# 1        2016   Skylines             London
# 2        2016   Skylines             London
# 3        2016   Skylines             London
# 4        2016   Skylines             London
# ...       ...        ...                ...
# 4698978  2016       Fire  Fire Ladder Truck
# 4698979  2016       Fire  Fire Ladder Truck
# 4698980  2016       Fire  Fire Ladder Truck
# 4698981  2016       Fire  Fire Ladder Truck
# 4698982  2016       Fire  Fire Ladder Truck
#
#                                                   Sets URL  \
# 0        https://cdn.rebrickable.com/media/sets/21034-1...
# 1        https://cdn.rebrickable.com/media/sets/21034-1...
# 2        https://cdn.rebrickable.com/media/sets/21034-1...
# 3        https://cdn.rebrickable.com/media/sets/21034-1...
# 4        https://cdn.rebrickable.com/media/sets/21034-1...
# ...                                                    ...
# 4698978  https://cdn.rebrickable.com/media/sets/60107-1...
# 4698979  https://cdn.rebrickable.com/media/sets/60107-1...
# 4698980  https://cdn.rebrickable.com/media/sets/60107-1...
# 4698981  https://cdn.rebrickable.com/media/sets/60107-1...
# 4698982  https://cdn.rebrickable.com/media/sets/60107-1...
#
#                           Part category                          Part name  \
# 0                                Plates                        Plate 4 x 8
# 1                                Plates                        Plate 4 x 8
# 2                                Plates                        Plate 4 x 8
# 3                                Plates                        Plate 4 x 8
# 4                                Plates                        Plate 4 x 8
# ...                                 ...                                ...
# 4698978  Plates Round Curved and Dishes  Plate Round 1 x 1 with Solid Stud
# 4698979  Plates Round Curved and Dishes  Plate Round 1 x 1 with Solid Stud
# 4698980  Plates Round Curved and Dishes  Plate Round 1 x 1 with Solid Stud
# 4698981  Plates Round Curved and Dishes  Plate Round 1 x 1 with Solid Stud
# 4698982  Plates Round Curved and Dishes  Plate Round 1 x 1 with Solid Stud
#
#         Part material         Part color     RGB Is Transparent?  \
# 0             Plastic          Dark Blue  0A3463           False
# 1             Plastic    Trans-Dark Blue  0020A0            True
# 2             Plastic          Dark Blue  0A3463           False
# 3             Plastic       Bright Green  4B9F4A           False
# 4             Plastic  Bright Light Blue  9FC3E9           False
# ...               ...                ...     ...             ...
# 4698978       Plastic   Trans-Clear Opal  FCFCFC            True
# 4698979       Plastic   Medium Dark Pink  F785B1           False
# 4698980       Plastic        Pastel Blue  5AC4DA           False
# 4698981       Plastic              Brown  583927           False
# 4698982       Plastic    Trans-Dark Pink  DF6695            True
#
#                                                   Part URL Set Price  \
# 0        https://cdn.rebrickable.com/media/parts/elemen...   53,3556
# 1        https://cdn.rebrickable.com/media/parts/elemen...   53,3556
# 2        https://cdn.rebrickable.com/media/parts/elemen...   53,3556
# 3        https://cdn.rebrickable.com/media/parts/elemen...   53,3556
# 4        https://cdn.rebrickable.com/media/parts/elemen...   53,3556
# ...                                                    ...       ...
# 4698978  https://cdn.rebrickable.com/media/parts/elemen...   24,8126
# 4698979  https://cdn.rebrickable.com/media/parts/elemen...   24,8126
# 4698980  https://cdn.rebrickable.com/media/parts/elemen...   24,8126
# 4698981  https://cdn.rebrickable.com/media/parts/elemen...   24,8126
# 4698982  https://cdn.rebrickable.com/media/parts/elemen...   24,8126
#
#         Number of reviews Star rating
# 0                      23         4,7
# 1                      23         4,7
# 2                      23         4,7
# 3                      23         4,7
# 4                      23         4,7
# ...                   ...         ...
# 4698978                11         4,5
# 4698979                11         4,5
# 4698980                11         4,5
# 4698981                11         4,5
# 4698982                11         4,5
#
# [4698983 rows x 14 columns]

# %% [markdown]
# # Clean the Dataframe

# %%
from Clean_data import *

Clean_Lego_df = clean_lego_data(Lego_df)
Clean_Lego_df = clean_columns_name(Clean_Lego_df)

# %%
Clean_Lego_df
# Out:
#          year theme_name         sets_name  \
# 0        2016   Skylines            London
# 1        2016   Skylines            London
# 3        2016   Skylines            London
# 4        2016   Skylines            London
# 5        2016   Skylines            London
# ...       ...        ...               ...
# 4698681  2017     Police  High-speed Chase
# 4698682  2017     Police  High-speed Chase
# 4698683  2017     Police  High-speed Chase
# 4698684  2017     Police  High-speed Chase
# 4698685  2017     Police  High-speed Chase
#
#                                                   sets_url  \
# 0        https://cdn.rebrickable.com/media/sets/21034-1...
# 1        https://cdn.rebrickable.com/media/sets/21034-1...
# 3        https://cdn.rebrickable.com/media/sets/21034-1...
# 4        https://cdn.rebrickable.com/media/sets/21034-1...
# 5        https://cdn.rebrickable.com/media/sets/21034-1...
# ...                                                    ...
# 4698681  https://cdn.rebrickable.com/media/sets/60138-1...
# 4698682  https://cdn.rebrickable.com/media/sets/60138-1...
# 4698683  https://cdn.rebrickable.com/media/sets/60138-1...
# 4698684  https://cdn.rebrickable.com/media/sets/60138-1...
# 4698685  https://cdn.rebrickable.com/media/sets/60138-1...
#
#                part_category                                     part_name  \
# 0                     Plates                                   Plate 4 x 8
# 1                     Plates                                   Plate 4 x 8
# 3                     Plates                                   Plate 4 x 8
# 4                     Plates                                   Plate 4 x 8
# 5                     Plates                                   Plate 4 x 8
# ...                      ...                                           ...
# 4698681  Minifig Accessories  Headwear Accessory Visor For Standard Helmet
# 4698682  Minifig Accessories  Headwear Accessory Visor For Standard Helmet
# 4698683  Minifig Accessories  Headwear Accessory Visor For Standard Helmet
# 4698684  Minifig Accessories  Headwear Accessory Visor For Standard Helmet
# 4698685  Minifig Accessories  Headwear Accessory Visor For Standard Helmet
#
#         part_material         part_color     rgb is_transparent?  \
# 0             Plastic          Dark Blue  0A3463           False
# 1             Plastic    Trans-Dark Blue  0020A0            True
# 3             Plastic       Bright Green  4B9F4A           False
# 4             Plastic  Bright Light Blue  9FC3E9           False
# 5             Plastic         Dark Brown  352100           False
# ...               ...                ...     ...             ...
# 4698681       Plastic                Tan  E4CD9E           False
# 4698682       Plastic              White  FFFFFF           False
# 4698683       Plastic       Trans-Orange  F08F1C            True
# 4698684       Plastic              Brown  583927           False
# 4698685       Plastic        Trans-Green  84B68D            True
#
#                                                   part_url     set_price  \
# 0        https://cdn.rebrickable.com/media/parts/elemen...  5.335560e+05
# 1        https://cdn.rebrickable.com/media/parts/elemen...  5.335560e+05
# 3        https://cdn.rebrickable.com/media/parts/elemen...  5.335560e+05
# 4        https://cdn.rebrickable.com/media/parts/elemen...  5.335560e+05
# 5        https://cdn.rebrickable.com/media/parts/elemen...  5.335560e+05
# ...                                                    ...           ...
# 4698681  https://cdn.rebrickable.com/media/parts/elemen...  3.814308e+10
# 4698682  https://cdn.rebrickable.com/media/parts/elemen...  3.814308e+10
# 4698683  https://cdn.rebrickable.com/media/parts/elemen...  3.814308e+10
# 4698684  https://cdn.rebrickable.com/media/parts/elemen...  3.814308e+10
# 4698685  https://cdn.rebrickable.com/media/parts/elemen...  3.814308e+10
#
#          number_of_reviews  star_rating
# 0                     23.0         47.0
# 1                     23.0         47.0
# 3                     23.0         47.0
# 4                     23.0         47.0
# 5                     23.0         47.0
# ...                    ...          ...
# 4698681               14.0         42.0
# 4698682               14.0         42.0
# 4698683               14.0         42.0
# 4698684               14.0         42.0
# 4698685               14.0         42.0
#
# [2329508 rows x 14 columns]

# %% [markdown]
# # Hypothesis

# %% [markdown]
# ### 1. Annual Patterns in Set Prices: Examine whether Lego set prices have followed a steady pattern over time. Consider whether prices have generally gone up, down, or unchanged for various themes.

# %% [markdown]
# ### 2. Popular Themes and Ratings: Check to see if any themes have a tendency to score better than others or to accumulate more reviews. Make an educated guess as to whether popular themes sustain high ratings year after year or whether there is variation.

# %% [markdown]
# ### 3. Impact of Part Material or Color on Set Price: Make a conjecture regarding the potential influence of part material or color on the set price. Sets with specific materials or colors, for example, may have varying prices because of their scarcity or desirability.

# %% [markdown]
# ### 4. Theme Success Over Time: Examine whether a particular theme has been more or less well-liked over time. Conjecture on whether a theme's popularity is constant or if it varies depending on a number of variables including media tie-ins, trends, etc.
