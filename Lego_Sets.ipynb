# %% [markdown]
# # Import the Libraries that are going to be used:

# %%
import pandas as pd

# %% [markdown]
# # Read the csv file

# %% [markdown]
# ## Before reading the csv file
#
# ### Instructions:
# 1. Download the Dataset from the page: https://www.kaggle.com/datasets/alessiasimone/lego-sets-and-price-1955-2023/.
# 2. After downloading extract the file in the location you want to use.
# 3. Then change the name of the file from Output.csv to which name you want to use.
# 4. Now you can enjoy the code by changing the name of the file in the read_csv.

# %%
Lego_df = pd.read_csv('lego_sets_data.csv', dtype={'column_9': int}, low_memory=False,sep=';')

# %%
Lego_df
# Out:
#          year Theme name  ... Number of reviews Star rating
# 0        2016   Skylines  ...                23         4,7
# 1        2016   Skylines  ...                23         4,7
# 2        2016   Skylines  ...                23         4,7
# 3        2016   Skylines  ...                23         4,7
# 4        2016   Skylines  ...                23         4,7
# ...       ...        ...  ...               ...         ...
# 4698978  2016       Fire  ...                11         4,5
# 4698979  2016       Fire  ...                11         4,5
# 4698980  2016       Fire  ...                11         4,5
# 4698981  2016       Fire  ...                11         4,5
# 4698982  2016       Fire  ...                11         4,5
#
# [4698983 rows x 14 columns]

# %% [markdown]
# # Clean the Dataframe

# %%
from Clean_data import clean_lego_data

Clean_Lego_df = clean_lego_data(Lego_df)

# %%
Clean_Lego_df
# Out:
#          year Theme name  ... Number of reviews Star rating
# 0        2016   Skylines  ...                23         4,7
# 1        2016   Skylines  ...                23         4,7
# 3        2016   Skylines  ...                23         4,7
# 4        2016   Skylines  ...                23         4,7
# 5        2016   Skylines  ...                23         4,7
# ...       ...        ...  ...               ...         ...
# 4698681  2017     Police  ...                14         4,2
# 4698682  2017     Police  ...                14         4,2
# 4698683  2017     Police  ...                14         4,2
# 4698684  2017     Police  ...                14         4,2
# 4698685  2017     Police  ...                14         4,2
#
# [2329508 rows x 14 columns]

# %% [markdown]
# # Hypothesis

# %% [markdown]
# ### 1. Yearly Trends in Set Prices: Investigate whether there's a consistent trend in Lego set prices over the years. Hypothesize if prices have generally increased, decreased, or remained stable across different themes.

# %% [markdown]
# ### 2. Popular Themes and Ratings: Explore if certain themes tend to receive higher star ratings or gather more reviews than others. Hypothesize whether popular themes consistently maintain high ratings or if there's variability across years.

# %% [markdown]
# ### 3. Effect of Part Material or Color on Set Price: Propose a hypothesis on whether the material or color of parts affects the set price. For instance, sets containing certain materials or colors might be priced differently due to rarity or demand.

# %% [markdown]
# ### 4. Theme Success Over Time: Explore whether certain themes have gained popularity or declined over the years. Hypothesize if the success of a theme is sustained or if it fluctuates based on various factors like trends, media tie-ins, etc.
